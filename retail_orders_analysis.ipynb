# %%
# import libraries
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (1.7.4.5)
# Requirement already satisfied: bleach in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (2025.6.15)
# Requirement already satisfied: charset-normalizer in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (3.4.2)
# Requirement already satisfied: idna in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (3.10)
# Requirement already satisfied: protobuf in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (6.31.1)
# Requirement already satisfied: python-dateutil>=2.5.3 in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (2.32.4)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (72.1.0)
# Requirement already satisfied: six>=1.10 in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (1.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/envs/luke_barousse/lib/python3.13/site-packages (from kaggle) (0.5.1)

# %%
# download dataset using kaggle api
import kaggle
# !kaggle datasets download ankitbansal06/retail-orders -f orders.csv #Dataset is imported
# Out:
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /Users/shlok_manan_13/.kaggle/kaggle.json'
# Warning: Your Kaggle API key is readable by other users on this system! To fix this, you can run 'chmod 600 /Users/shlok_manan_13/.kaggle/kaggle.json'
# Dataset URL: https://www.kaggle.com/datasets/ankitbansal06/retail-orders
# License(s): CC0-1.0
# orders.csv: Skipping, found more recently modified local copy (use --force to force download)

# %%
# read data from the file and handle null values
import pandas as pd
df = pd.read_csv('orders.csv', na_values=['Not Available', 'unknown']) # to convert the following values to NaN -- IMPORTANT

# %%
# check if the data is appropriate
df['ship_mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
# rename column names, make them lower case and replace space with underscore
df.columns = [i.strip().lower().replace(' ', '_') for i in df.columns] #rename the column names to standard format

# %%
# derive new columns discount, sale_price and profit
df['discount'] = df['list_price'] * df['discount_percent'] * 0.01
df['sale_price'] = df['list_price'] - df['discount']
df['profit'] = df['sale_price'] - df['cost_price']

# %%
# covert order date from object data type to datetime
df['order_date'] = pd.to_datetime(df['order_date'], format='%Y-%m-%d') #Convert the data type from object(string) to datetime

# %%
# drop cost_price, list_price and discount_percent columns
df.drop(columns=['cost_price','list_price','discount_percent'],inplace=True) #columns which are not of use are dropped

# %%
# removing the duplicates
df.drop_duplicates(inplace=True)

# %%
df.sample(10)
# Out:
#       order_id       ship_mode      segment        country           city  \
# 3796      3797  Standard Class     Consumer  United States      San Diego
# 1050      1051     First Class    Corporate  United States   Philadelphia
# 1647      1648     First Class  Home Office  United States   Philadelphia
# 5337      5338  Standard Class    Corporate  United States     Scottsdale
# 5869      5870  Standard Class  Home Office  United States       Cheyenne
# 9309      9310  Standard Class     Consumer  United States  San Francisco
# 2729      2730  Standard Class     Consumer  United States        Seattle
# 5940      5941    Second Class     Consumer  United States    Los Angeles
# 3182      3183    Second Class    Corporate  United States       Columbia
# 1028      1029  Standard Class    Corporate  United States     Hackensack
#
#              state  postal_code region         category sub_category  \
# 3796    California        92037   West  Office Supplies          Art
# 1050  Pennsylvania        19134   East        Furniture  Furnishings
# 1647  Pennsylvania        19140   East  Office Supplies    Fasteners
# 5337       Arizona        85254   West  Office Supplies        Paper
# 5869       Wyoming        82001   West        Furniture       Chairs
# 9309    California        94110   West  Office Supplies          Art
# 2729    Washington        98105   West  Office Supplies          Art
# 5940    California        90049   West       Technology  Accessories
# 3182      Maryland        21044   East       Technology  Accessories
# 1028    New Jersey         7601   East  Office Supplies        Paper
#
#            product_id  quantity  discount  sale_price  profit
# 3796  OFF-AR-10003179         4       1.6        38.4    -1.6
# 1050  FUR-FU-10000293         2       5.1       164.9    24.9
# 1647  OFF-FA-10001135         2       0.0         0.0     0.0
# 5337  OFF-PA-10000062         7      12.4       297.6     7.6
# 5869  FUR-CH-10001215         4      64.0      1536.0   156.0
# 9309  OFF-AR-10000034         6       1.5        28.5    -1.5
# 2729  OFF-AR-10001547         3       0.3         9.7    -0.3
# 5940  TEC-AC-10001465        12       8.8       431.2    61.2
# 3182  TEC-AC-10004666         3      16.6       813.4   153.4
# 1028  OFF-PA-10000474         5       9.0       171.0    11.0
